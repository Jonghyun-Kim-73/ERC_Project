# %%
import pandas as pd
import matplotlib.pylab as plt

# %%
db = pd.read_csv('Log[2020-11-18][18_10_53].txt')

# %%
out = ['ZINST103', 'WFWLN1', 'WFWLN2', 'WFWLN3', 'ZINST100', 'ZINST101', 'ZINST85', 'ZINST86',
       'ZINST87', 'ZINST99', 'UCHGUT', 'UCOLEG1', 'UCOLEG2', 'UCOLEG3', 'UPRZ', 'UUPPPL', 'WNETLD',
       'ZINST63', 'ZINST65', 'ZINST79', 'ZINST80', 'ZINST81', 'ZINST70', 'ZINST72', 'ZINST73',
       'ZINST75']

# %%
db
# Out:
#     #SYMBOL NAME  KFIGIV  KJMVXE  KSENS  KZRODN  NBANK  NCRODB  NCRSTEP  \
# 0              0       1       1    300     228      8       8      228
# 1              0       1       1    300     228      8       8      228
# 2              0       1       1    300     228      8       8      228
# 3              0       1       1    300     228      8       8      228
# 4              0       1       1    300     228      8       8      228
# ..           ...     ...     ...    ...     ...    ...     ...      ...
# 90             0       1       1    300     228      8       8      228
# 91             0       1       1    300     228      8       8      228
# 92             0       1       1    300     228      8       8      228
# 93             0       1       1    300     228      8       8      228
# 94             0       1       1    300     228      8       8      228
#
#     NZOVLAP  NZON  ...   cZINST63    cZINST65    cZINST79   cZINST80  \
# ...

# %%
for key in out:
    print(key)
    db[f'c{key}'][5:].plot(label='A')
    db[f'{key}'][5:].plot(label='B')
    plt.legend()
    plt.show()
# Out:
# ZINST103
# WFWLN1
# WFWLN2
# WFWLN3
# ZINST100
# ZINST101
# ZINST85
# ZINST86
# ZINST87
# ZINST99
# UCHGUT
# UCOLEG1
# UCOLEG2
# UCOLEG3
# UPRZ
# UUPPPL
# WNETLD
# ZINST63
# ZINST65
# ZINST79
# ZINST80
# ZINST81
# ZINST70
# ZINST72
# ZINST73
# ZINST75
